# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
from torch.quantization import QuantStub, DeQuantStub, prepare_qat, convert

# %%
# -----------------------------
# 1. Define the FOMO-Based Model
# -----------------------------
class FOMONet(nn.Module):
    def __init__(self, num_classes=2):
        super(FOMONet, self).__init__()
        self.quant = QuantStub()
        self.dequant = DeQuantStub()

        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d((1, 1))
        )

        self.classifier = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.quant(x)
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        x = self.dequant(x)
        return x

# %%
# -----------------------------
# 2. Prepare Dataset
# -----------------------------
class PneumoniaMNIST(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img, label = self.images[idx], self.labels[idx]
        if self.transform:
            img = self.transform(img)
        label = torch.tensor(label, dtype=torch.long).squeeze()  # Ensure labels are 1D tensors
        return img, label

# Load PneumoniaMNIST dataset
npz_file = np.load('PneumoniaMNIST.npz', allow_pickle=False)
train_images, train_labels = npz_file['train_images'], npz_file['train_labels']
val_images, val_labels = npz_file['val_images'], npz_file['val_labels']
test_images, test_labels = npz_file['test_images'], npz_file['test_labels']

# Normalize and transform the dataset
transform_train = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

transform_eval = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = PneumoniaMNIST(train_images, train_labels, transform=transform_train)
val_dataset = PneumoniaMNIST(val_images, val_labels, transform=transform_eval)
test_dataset = PneumoniaMNIST(test_images, test_labels, transform=transform_eval)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
# -----------------------------
# 3. Initialize Model and Prepare for QAT
# -----------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = FOMONet(num_classes=2).to(device)

# Print the number of parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

total_params = count_parameters(model)
print(f"Total trainable parameters: {total_params}")

# Prepare for QAT
model.qconfig = torch.quantization.get_default_qat_qconfig('fbgemm')
prepare_qat(model, inplace=True)

# %%
# -----------------------------
# 4. Define Training and Evaluation Functions
# -----------------------------
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=15):
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        running_corrects = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            running_corrects += torch.sum(preds == labels)
            total += labels.size(0)

        epoch_loss = running_loss / total
        epoch_acc = running_corrects.double() / total
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.2%}')

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_corrects = 0
        val_total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                _, preds = torch.max(outputs, 1)
                val_corrects += torch.sum(preds == labels)
                val_total += labels.size(0)

        val_epoch_loss = val_loss / val_total
        val_epoch_acc = val_corrects.double() / val_total
        print(f'Epoch {epoch+1}/{num_epochs}, Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.2%}')

# %%
# -----------------------------
# 5. Train and Quantize the Model
# -----------------------------
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=15)

# Convert to quantized model
model.eval()
quantized_model = convert(model, inplace=True)

# %%
# -----------------------------
# 6. Evaluate the Quantized Model
# -----------------------------
def evaluate_model(model, test_loader):
    model.eval()
    test_loss = 0.0
    test_corrects = 0
    test_total = 0
    all_preds = []
    all_labels = []
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to("cpu"), labels.to("cpu")
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.tolist())
            all_labels.extend(labels.tolist())
            test_corrects += torch.sum(preds == labels)
            test_total += labels.size(0)

    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')
    test_epoch_loss = test_loss / test_total
    test_epoch_acc = test_corrects.double() / test_total
    print(f"Test Loss: {test_epoch_loss:.4f}, Accuracy: {test_epoch_acc:.2%}")
    print(f"Precision: {precision:.2%}, Recall: {recall:.2%}, F1 Score: {f1:.2%}")

# Evaluation
evaluate_model(quantized_model, test_loader)

# %%
# quantized model to TorchScript
scripted_model = torch.jit.script(quantized_model)

# the scripted model
torchscript_path = "fomo_quantized_model.pt"
scripted_model.save(torchscript_path)
print(f"TorchScript model saved to {torchscript_path}")
# Out:
# TorchScript model saved to fomo_quantized_model.pt

# %%
# !pip install onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx) (4.25.5)
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 66.5 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0

# %%
# the original non-quantized model
non_quantized_model = FOMONet(num_classes=2)
non_quantized_model.eval()

# Dummy input for ONNX export
dummy_input = torch.randn(1, 1, 64, 64)

# Export the model to ONNX
onnx_path = "fomo_model_non_quantized.onnx"
torch.onnx.export(
    non_quantized_model,
    dummy_input,
    onnx_path,
    export_params=True,
    opset_version=13,
    do_constant_folding=True,
    input_names=["input"],
    output_names=["output"],
    dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}}
)
print(f"ONNX model saved to {onnx_path}")
# Out:
# ONNX model saved to fomo_model_non_quantized.onnx

# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 40.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.20.1

# %%
import onnx
import onnxruntime as ort

# Load the ONNX model
onnx_model = onnx.load(onnx_path)
onnx.checker.check_model(onnx_model)

# Test ONNX runtime
ort_session = ort.InferenceSession(onnx_path)
example_input = np.random.rand(1, 1, 64, 64).astype(np.float32)
ort_inputs = {"input": example_input}
ort_outs = ort_session.run(None, ort_inputs)
print(f"Inference output from ONNX model: {ort_outs}")

#  logits to probabilities
logits = torch.tensor(ort_outs[0])
probabilities = F.softmax(logits, dim=1)  # softmax
print(f"Probabilities: {probabilities}")

# Verify
predicted_class = probabilities.argmax(dim=1).item()
print(f"Predicted Class: {predicted_class}")
# Out:
# Inference output from ONNX model: [array([[ 0.01150238, -0.03886358]], dtype=float32)]
# Probabilities: tensor([[0.5126, 0.4874]])
# Predicted Class: 0

# %%
import os

# Path to your ONNX model file
onnx_model_path = "fomo_model_non_quantized.onnx"

# Get the file size
onnx_file_size = os.path.getsize(onnx_model_path) / (1024 * 1024)  # Convert to MB
print(f"ONNX Model Size: {onnx_file_size:.2f} MB")

# BLE 33 Memory Limit
ble_33_flash_limit = 1

if onnx_file_size <= ble_33_flash_limit:
    print("The model fits within the BLE 33 memory limit!")
else:
    print("The model exceeds the BLE 33 memory limit. Consider further optimization.")
# Out:
# ONNX Model Size: 0.37 MB
# The model fits within the BLE 33 memory limit!

# %%
import os
import numpy as np
from PIL import Image

# Load the .npz file
npz_file = np.load('PneumoniaMNIST.npz', allow_pickle=False)
train_images, train_labels = npz_file['train_images'], npz_file['train_labels']
val_images, val_labels = npz_file['val_images'], npz_file['val_labels']
test_images, test_labels = npz_file['test_images'], npz_file['test_labels']

# Create directories for images
output_dir = "EdgeImpulseDataset"
splits = ['train', 'val', 'test']
classes = ['normal', 'pneumonia']  # Adjust based on your dataset

for split in splits:
    for class_name in classes:
        os.makedirs(os.path.join(output_dir, split, class_name), exist_ok=True)

# Function to save images
def save_images(images, labels, split):
    for i, (img, label) in enumerate(zip(images, labels)):
        label = int(label)  # Ensure label is an integer
        class_name = classes[label]
        img = Image.fromarray((img * 255).astype(np.uint8))  # Scale to 0-255 if needed
        img = img.convert('L')  # Convert to grayscale if necessary
        filename = os.path.join(output_dir, split, class_name, f"{split}_{i}.jpg")
        img.save(filename)

#  train, val, and test images
save_images(train_images, train_labels, 'train')
save_images(val_images, val_labels, 'val')
save_images(test_images, test_labels, 'test')

print(f"Dataset saved to {output_dir}.")
# Out:
# <ipython-input-14-d61007e7baf5>:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   label = int(label)  # Ensure label is an integer
# Dataset saved to EdgeImpulseDataset.

# %%
# !zip -r EdgeImpulseDataset.zip EdgeImpulseDataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: EdgeImpulseDataset/val/pneumonia/val_267.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_494.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_59.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_107.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_375.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_401.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_300.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_368.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_113.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_379.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_273.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_0.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_56.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_6.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_181.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_428.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_65.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_148.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_1.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_324.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_152.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_154.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_145.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_507.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_57.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_167.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_71.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_221.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_460.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_405.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_239.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_380.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_268.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_422.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_86.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_143.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_445.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_320.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_306.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_77.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_477.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_286.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_294.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_18.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_137.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_255.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_214.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_142.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_141.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_412.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_470.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_133.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_96.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_387.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_105.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_370.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_108.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_232.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_512.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_376.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_97.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_307.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_128.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_435.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_195.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_51.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_48.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_508.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_67.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_430.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_196.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_344.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_333.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_418.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_21.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_140.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_8.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_9.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_289.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_397.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_314.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_208.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_511.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_313.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_351.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_73.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_84.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_431.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_465.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_440.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_253.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_278.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_125.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_446.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_41.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_176.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_503.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_331.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_172.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_127.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_245.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_123.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_369.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_523.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_457.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_262.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_144.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_393.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_339.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_458.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_225.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_213.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_180.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_91.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_301.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_317.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_153.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_94.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_264.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_323.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_61.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_292.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_473.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_64.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_25.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_367.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_520.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_487.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_275.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_20.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_29.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_117.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_222.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_419.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_408.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_423.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_116.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_243.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_234.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_513.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_290.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_325.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_469.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_194.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_158.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_497.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_265.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_191.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_504.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_139.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_390.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_474.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_15.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_283.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_43.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_399.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_517.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_211.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_231.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_361.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_439.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_359.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_170.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_218.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_75.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_121.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_425.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_99.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_112.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_150.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_414.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_348.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_356.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_263.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_110.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_120.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_510.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_377.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_515.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_188.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_450.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_50.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_434.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_332.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_169.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_111.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_134.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_319.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_501.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_229.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_266.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_316.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_274.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_42.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_467.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_126.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_260.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_95.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_384.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_39.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_461.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_272.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_448.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_247.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_17.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_302.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_347.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_109.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_499.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_442.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_26.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_322.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_98.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_410.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_270.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_269.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_327.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_492.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_303.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_238.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_160.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_315.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_489.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_138.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_250.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_495.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_122.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_249.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val_100.jpg (stored 0%)
#   adding: EdgeImpulseDataset/val/pneumonia/val